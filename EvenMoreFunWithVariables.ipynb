# %% [markdown]
# # Trivia Time: Collections Practice Set
#
# Exercises for [LSP Sections 4.7–4.18](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#regular-variables-and-collection-variables) — lists, tuples, sets, dictionaries, and indexing/slicing.
#
# We'll build up a little psycholinguistics trivia game using nothing but lists, tuples, sets, and dictionaries. Go through them in order, since later ones sometimes reuse variables from earlier ones. Work in pairs or small groups. Two is probably good, max three in a group. Where it says **Predict**, stop and actually guess (out loud, or in a markdown cell) before running the code. It's fine if you don't finish everything. Understanding some of these well is much more important than rushing through all of them.

# %% [markdown]
# ---

# %% [markdown]
# ## Warm-up: same facts, four containers
#
# Before we try each collection type on its own, let's look at the same small set of facts stored four different ways.

# %% [markdown]
# ### 1. Type detective
#
# Predict what `type()` will report for each of the four variables below, and predict whether `print()`​ing each one will show the items in the same order every time. Then run the cell and check.
#
# Background: [LSP 4.7 Regular variables and collection variables](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#regular-variables-and-collection-variables), [4.10 Collection variables](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#collection-variables).

# %% [markdown]
# - Michif, Peter Bakker, creolistics, 1997; type: list
# - Michif, Peter Bakker, 1997, creolistics; type: tuple
# - creolistics, Michif, Peter Bakker, 1997; type: set
# - language: Michif, linguist: Peter Bakker, year: 1997: area: creolistics; type: dict

# %%
trivia_list = ["Michif", "Peter Bakker", 1997, "creolistics"]
trivia_tuple = ("Michif", "Peter Bakker", 1997, "creolistics") 
trivia_set = {"Michif", "Peter Bakker", 1997, "creolistics"}
trivia_dict = {"language": "Michif", "linguist": "Peter Bakker", "year": 1997, "area": "creolistics"}

type(trivia_list)
# Out:
# list

# %%
type(trivia_tuple)
# Out:
# tuple

# %%
type(trivia_set)
# Out:
# set

# %%
type(trivia_dict)
# Out:
# dict

# %%
print(trivia_list)
# Out:
# ['Michif', 'Peter Bakker', 1997, 'creolistics']

# %%
print(trivia_tuple)
# Out:
# ('Michif', 'Peter Bakker', 1997, 'creolistics')

# %%
print(trivia_set)
# Out:
# {'Michif', 'creolistics', 'Peter Bakker', 1997}

# %%
trivia_dict
# Out:
# {'language': 'Michif',
#  'linguist': 'Peter Bakker',
#  'year': 1997,
#  'area': 'creolistics'}

# %% [markdown]
# - Set reorders the items
# - Irrelevant to the activity above

# %% [markdown]
# **Discuss:** which of these four keep the items in the order you typed them, and which don't guarantee that? Which ones would let you store the value `"Python"` twice?
#
# **Try it:** in a new cell below, try `trivia_list[0]`, then try the same `[0]` indexing on `trivia_set` and on `trivia_dict`. Two of these will fail. Predict which ones before you run it, then read the error message closely — what is Python actually complaining about in each case?

# %%
# try trivia_list[0], trivia_set[0], and trivia_dict[0] here
trivia_list[0]
trivia_set[0]
trivia_dict[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 # try trivia_list[0], trivia_set[0], and trivia_dict[0] here
#       2 trivia_list[0]
# ----> 3 trivia_set[0]
#       4 trivia_dict[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ---

# %% [markdown]
# ## Indexing & slicing
#
# I didn't do a great job explaining indexing and slicing last week, so let me try again. Also, remember you can consult [LSP 4.17 Indexing and slicing](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#indexing-and-slicing) and [4.18 Slices](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#slices).
#
# In Python, every list (and string, and tuple) is [**0-indexed**](https://en.wikipedia.org/wiki/Zero-based_numbering): the first item is at position `0`, not `1`. Negative indices count backwards from the end, so `-1` is the last item, `-2` is second-to-last, and so on. If it helps, you can think about it in terms of steps. Imagine that the Python list is like a sidewalk, made out of square cement blocks. When you step onto the sidewalk, you are standing on a block. This is your starting position. To get to the block you are already standing on, you would take 0 steps, because you are already there. That first block has an index of 0, which is the number of steps it takes to get there from the start. You take [one step](https://www.youtube.com/watch?v=Lixm0ajWCi8&list=RDLixm0ajWCi8&start_radio=1), and now you are on the second block, so that block gets the index of "1". Maybe this helps?
#
# Now, imagine you are at the end of the sidewalk. You have stepped off of the sidewalk, and you want to get back on. You need to take one step backwards (-1) to get back onto that last block. If you are walking backwards from a position just off of the sidewalk, that last block is at position -1. Does this help? I hope so. The best thing is still to just play around with it and get used to it.
#
# A single index, like `mylist[3]`, gives you back **one item** — whatever type that item is.
#
# A **slice**, written `mylist[start:stop]`, gives you back a **new list** containing everything from position `start` up to *but not including* position `stop`. This last bit, "not including stop", can be quite confusing at first — `mylist[0:3]` gives you 3 items (indices 0, 1, 2), not 4. If it helps, think about Python counting through all the different positions. When it gets to the one in the "stop" position, it say "No, no, no! Stop! Not this one!" In Computational Linguistics you will probably learn about "stop words". These are all the words you _don't_ want to do something with. For example, when analyzing a text, maybe you don't want your analysis to include all of the most common words like "and", "a", "the", so you give your Python script a list of these "stop words", which it should ignore. The stop position in the slice is kind of the same idea.
#
# You can leave either side blank: `mylist[:3]` means "from the beginning up to 3", and `mylist[3:]` means "from 3 to the end".
#
# There's an optional third part, the **step**: `mylist[start:stop:step]` skips items. `mylist[::2]` takes every 2nd item across the whole list. `mylist[::-1]` steps backwards through the whole list.
#
# | Slice | Meaning |
# |---|---|
# | `mylist[0]` | just the first item (not a list) |
# | `mylist[0:1]` | a *list* containing just the first item |
# | `mylist[:3]` | first 3 items |
# | `mylist[-3:]` | last 3 items |
# | `mylist[2:5]` | items at index 2, 3, 4 |
# | `mylist[::2]` | every 2nd item |
# | `mylist[::-1]` | the whole list, reversed |
#
# **Predict** first: what's the difference in *type* between `mylist[0]` and `mylist[0:1]`? Check with `type()` once you've built the list below.

# %%
mylist = ["Sioux Falls", "Hagerstown", "Marstons Mills", "Sogndal", "Los Angeles", "Aarhus"]

# %%
mylist[0]
# Out:
# 'Sioux Falls'

# %%
type(mylist[0])
# Out:
# str

# %%
mylist[0:1]
# Out:
# ['Sioux Falls']

# %%
type(mylist[0:1])
# Out:
# list

# %% [markdown]
# ### 2. Meet the trivia facts
#
# Here's a list of 12 psycholinguistics facts to slice up. Each one is backed by a real source -- see the reference list right after this cell if you want to go read the original.

# %%
trivia_facts = [
    "Babies can tell apart the sounds of every human language until about 8 months old, then get better at their native sounds and worse at foreign ones. (Werker & Tees, 1984)",
    "In 2011, lexicographers found that the verb 'run' has 645 distinct meanings in the Oxford English Dictionary -- more than any other English word, overtaking the previous record-holder, 'set'. (Wolman, 2011)",
    "People typically speak at a rate of about 150 words per minute in conversation. (Tauroza & Allison, 1990)",
    "The Piraha language of the Amazon has no words for exact numbers. (Frank et al., 2008)",
    "Broca's area, involved in speech production, was first identified in 1861. (Broca, 1861)",
    "Age at first exposure to a second language strongly predicts how strong a foreign accent someone ends up with. (Oyama, 1976)",
    "American Sign Language is not a signed version of English -- it has its own grammar. (Stokoe, 1960)",
    "The 'tip of the tongue' feeling has been documented in speakers of dozens of unrelated languages. (Schwartz, 1999)",
    "Reading a sentence about kicking activates the motor cortex a little, even though you're not moving. (Hauk, Johnsrude, & Pulvermuller, 2004)",
    "The average 20-year-old native English speaker knows about 42,000 words. (Brysbaert, Stevens, Mandera, & Keuleers, 2016)",
    "Dolphins have signature whistles that work a lot like names. (Sayigh, Tyack, Wells, & Scott, 1990)",
    "Bilingual speakers often report feeling like a slightly different person in each language. (Pavlenko, 2006)",
]

# %% [markdown]
# **References for the facts above**
#
# - Broca, P. (1861). Remarques sur le siège de la faculté du langage articulé, suivies d'une observation d'aphémie. *Bulletin de la Société Anatomique de Paris, 36*, 330–357.
# - Brysbaert, M., Stevens, M., Mandera, P., & Keuleers, E. (2016). How many words do we know? Practical estimates of vocabulary size dependent on word definition, the degree of language input, and the participant's age. *Frontiers in Psychology, 7*, 1116.
# - Frank, M. C., Everett, D. L., Fedorenko, E., & Gibson, E. (2008). Number as a cognitive technology: Evidence from Pirahã language and cognition. *Cognition, 108*(3), 819–824.
# - Hauk, O., Johnsrude, I., & Pulvermüller, F. (2004). Somatotopic representation of action words in human motor and premotor cortex. *Neuron, 41*(2), 301–307.
# - Oyama, S. (1976). A sensitive period for the acquisition of a nonnative phonological system. *Journal of Psycholinguistic Research, 5*(3), 261–283.
# - Pavlenko, A. (2006). Bilingual selves. In A. Pavlenko (Ed.), *Bilingual minds: Emotional experience, expression, and representation* (pp. 1–33). Multilingual Matters.
# - Sayigh, L. S., Tyack, P. L., Wells, R. S., & Scott, M. D. (1990). Signature whistles of free-ranging bottlenose dolphins, *Tursiops truncatus*: Stability and mother-offspring comparisons. *Behavioral Ecology and Sociobiology, 26*(4), 247–260.
# - Schwartz, B. L. (1999). Sparkling at the end of the tongue: The etiology of tip-of-the-tongue phenomenology. *Psychonomic Bulletin & Review, 6*(3), 379–393.
# - Stokoe, W. C. (1960). *Sign language structure: An outline of the visual communication systems of the American deaf* (Studies in Linguistics, Occasional Papers No. 8). University of Buffalo.
# - Tauroza, S., & Allison, D. (1990). Speech rates in British English. *Applied Linguistics, 11*(1), 90–105.
# - Werker, J. F., & Tees, R. C. (1984). Cross-language speech perception: Evidence for perceptual reorganization during the first year of life. *Infant Behavior and Development, 7*(1), 49–63.
# - Wolman, D. (2011, May 30). Has 'run' run amok? It has 645 meanings ... so far. *NPR*.

# %% [markdown]
# ### 3. Slice practice
#
# Predict each result before running it. Fill in the blanks below (there's a comment for each one to guide you).
#
# **Extend:** for the last one, find a way to get the facts in reverse order *without* using `.reverse()` or `reversed()` — slicing alone should do it.

# %%
# a. the very first fact (should be a string, not a list)
trivia_facts[0]

# b. the very first fact as a one-item list
trivia_facts[0:1]

# c. the last fact, using a negative index
trivia_facts[-1]

# d. the first 3 facts
trivia_facts[0:3]

# e. the last 3 facts
trivia_facts[-3:]

# f. facts 4 through 7 (the middle chunk)
trivia_facts[3:7]

# g. every 3rd fact, starting from the beginning
trivia_facts[0::3]

# h. Extend: all the facts in reverse order, using slicing only
trivia_facts[::-1]
# Out:
# ['Bilingual speakers often report feeling like a slightly different person in each language. (Pavlenko, 2006)',
#  'Dolphins have signature whistles that work a lot like names. (Sayigh, Tyack, Wells, & Scott, 1990)',
#  'The average 20-year-old native English speaker knows about 42,000 words. (Brysbaert, Stevens, Mandera, & Keuleers, 2016)',
#  "Reading a sentence about kicking activates the motor cortex a little, even though you're not moving. (Hauk, Johnsrude, & Pulvermuller, 2004)",
#  "The 'tip of the tongue' feeling has been documented in speakers of dozens of unrelated languages. (Schwartz, 1999)",
#  'American Sign Language is not a signed version of English -- it has its own grammar. (Stokoe, 1960)',
#  'Age at first exposure to a second language strongly predicts how strong a foreign accent someone ends up with. (Oyama, 1976)',
#  "Broca's area, involved in speech production, was first identified in 1861. (Broca, 1861)",
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Lists: the workhorse
#
# Reference: [LSP 4.10.1 Lists](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#lists), [4.15 Object methods](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#object-methods).

# %% [markdown]
# ### 4. Building and reshaping a list
#
# Use the trivia categories below. For each task, look up the right list method (try `dir(trivia_categories)` if you get stuck, or check the book section above).

# %%
trivia_categories = ["Phonology", "Bilingualism", "Neurolinguistics"]

# %%
# a. add "Language Acquisition" to the end of the list
trivia_categories.append("Language Acquisition")

# b. insert "Linguists" at the very front of the list
trivia_categories.insert(0, "Linguists")

# c. remove "Bilingualism" from the list
trivia_categories.remove("Bilingualism") 

# d. remove and print the last item in the list (one method does both)
trivia_categories.pop(-1)

# e. sort the remaining categories alphabetically
trivia_categories.sort()

# f. reverse the sorted list
trivia_categories.reverse()

# %%
print(trivia_categories)
# Out:
# ['Phonology', 'Neurolinguistics', 'Linguists']

# %% [markdown]
# ### 5. Copy vs. reference
#
# Predict what happens before you run this.

# %% [markdown]
# List a will be unchanged, while List b will now have Pragmatics added at the end of the list.

# %%
list_a = ["Phonology", "Syntax", "Semantics"]
list_b = list_a
list_b.append("Pragmatics")

print(list_a)
print(list_b)
# Out:
# ['Phonology', 'Syntax', 'Semantics', 'Pragmatics']
# ['Phonology', 'Syntax', 'Semantics', 'Pragmatics']

# %% [markdown]
# I thought that list b would simply be a copy of list a, and that list a would be unchanged. Therefore, I think that the = actually links these two and makes them truly equal, not just a copy. In other words, it didn't make a new list, it assigned the two variables to the same list.

# %% [markdown]
# **Discuss:** why did modifying `list_b` also change `list_a`, when we never touched `list_a` directly? What do you think `list_b = list_a` actually did — did it make a new list, or something else?
#
# **Try it:** redo this using `list_b = list_a.copy()` (or `list_a[:]`, a slice of the whole thing) instead of `list_b = list_a`. Does `list_a` change this time?

# %%
list_a = ["Phonology", "Syntax", "Semantics"]
list_b = list_a.copy()
list_b.append("Pragmatics")

print(list_a)
print(list_b)
# Out:
# ['Phonology', 'Syntax', 'Semantics']
# ['Phonology', 'Syntax', 'Semantics', 'Pragmatics']

# %% [markdown]
# ---

# %% [markdown]
# ## Tuples: facts that don't change
#
# Reference: [LSP 4.11 Tuples](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#tuples).

# %% [markdown]
# ### 6. Locked in
#
# Predict: what happens if you try to change an item in a tuple, the same way you would in a list?

# %% [markdown]
# Will there be an error message?

# %%
trivia_answer_key = ("Chomsky", "phoneme", "Wernicke's area")

# try changing the first item, e.g. trivia_answer_key[0] = "Skinner"
trivia_answer_key[1] = "morpheme"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 4
#       1 trivia_answer_key = ("Chomsky", "phoneme", "Wernicke's area")
#       2
#       3 # try changing the first item, e.g. trivia_answer_key[0] = "Skinner"
# ----> 4 trivia_answer_key[1] = "morpheme"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **Discuss:** you got a `TypeError`. Given what that error says, why might someone deliberately choose a tuple over a list for something like an answer key?

# %% [markdown]
# ### 7. Unpacking
#
# Tuples (and lists) can be unpacked into separate variables in one line. Try it:

# %%
trivia_tuple = ("Python", "Noam Chomsky", 1991, "phoneme")

language, linguist, year, unit = trivia_tuple
print(language)
print(linguist)
print(year)
print(unit)
# Out:
# Python
# Noam Chomsky
# 1991
# phoneme

# %% [markdown]
# **Extend:** here's a neat trick that uses the exact same idea. Given the two variables below, swap their values *in one line*, without creating a third helper variable:
#
# ```python
# a = "left"
# b = "right"
# ```
#
# (Hint: what happens if you write `a, b = b, a`?)

# %%
a = "left"
b = "right"

# swap a and b in one line here
a , b = b, a

print(a)
print(b)
# Out:
# right
# left

# %% [markdown]
# ---

# %% [markdown]
# ## Sets: dedup (deduplicate) and compare
#
# Reference: [LSP 4.14 Sets](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#sets).

# %% [markdown]
# ### 8. Cleaning up a messy survey
#
# We asked the class which trivia categories they liked, and got a messy list back with repeats. Turn it into a set to see the unique categories, and use `len()` to compare how many answers we collected vs. how many *distinct* categories there actually were.
#
# Then again, since this is a survey, we might want to know how many times people mentioned each category. One way to do this is to get help from our old friend `pandas`. `pd.Series(...).value_counts()` should give us what we need. Just remember to do `import pandas as pd` first.

# %%
category_survey = ["Phonology", "Bilingualism", "Phonology", "Neurolinguistics",
                    "Linguists", "Bilingualism", "Phonology"]

# %%
import pandas as pd

# %%
# a. turn category_survey into a set
category_survey_set = set((category_survey))
print(category_survey_set)

# b. how many responses were collected? (len of the original list)
len(category_survey)

# c. how many distinct categories were there? (len of the set)
len(category_survey_set)

# d. how many times was each category mentioned? (hint: pd.Series(category_survey).value_counts())
pd.Series(category_survey).value_counts()
# Out:
# {'Neurolinguistics', 'Bilingualism', 'Linguists', 'Phonology'}
# Phonology           3
# Bilingualism        2
# Neurolinguistics    1
# Linguists           1
# Name: count, dtype: int64

# %% [markdown]
# ### 9. Comparing favorites with a partner
#
# Sets have their own comparison operators, borrowed straight from math-class Venn diagrams:
#
# | Operator | Name | Meaning |
# |---|---|---|
# | `a & b` | intersection | items in **both** `a` and `b` |
# | `a \| b` | union | items in **either** `a` or `b` (combined, no duplicates) |
# | `a - b` | difference | items in `a` but **not** in `b` |
# | `a ^ b` | symmetric difference | items in **exactly one** of `a` or `b`, not both |
# | `x in a` | membership | `True` if `x` is somewhere in `a` |
#
# Here are two students' favorite trivia categories. Use set operations to answer each question in the comments below.

# %%
my_categories = {"Phonology", "Neurolinguistics", "Bilingualism"}
partner_categories = {"Language Acquisition", "Neurolinguistics", "Linguists"}

# %%
# a. which categories do we both like? (intersection)
my_categories & partner_categories

# b. which categories, combined, does at least one of us like? (union)
my_categories | partner_categories

# c. which categories do I like that my partner doesn't? (difference)
my_categories - partner_categories

# d. which categories are liked by exactly one of us, not both? (symmetric difference)
my_categories ^ partner_categories

# e. is "Neurolinguistics" in my_categories? use `in` to check
'Neurolinguistics' in my_categories
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ## Dictionaries: labeled trivia cards
#
# Reference: [LSP 4.12 Dictionaries](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#dictionaries), [4.13.2 A dictionary of …](https://ethanweed.github.io/pythonbook/02.02-more_python_concepts.html#a-dictionary-of).

# %% [markdown]
# ### 10. Building a dictionary with `zip`
#
# `zip()` takes two (or more) lists and pairs them up position by position: item 1 from the first list with item 1 from the second, item 2 with item 2, and so on. On its own it gives you back a `zip` object, which doesn't print anything useful until you turn it into something else, like a `list()` or a `dict()`:
#
# ```python
# letters = ["a", "b", "c"]
# numbers = [1, 2, 3]
#
# list(zip(letters, numbers))
# # [('a', 1), ('b', 2), ('c', 3)]
# ```
#
# Feed that same pairing straight into `dict()` and each pair becomes a key-value pair instead of a tuple:
#
# ```python
# dict(zip(letters, numbers))
# # {'a': 1, 'b': 2, 'c': 3}
# ```
#
# Here are matched lists of trivia questions and answers. Use `zip()` and `dict()` together to combine them into a single dictionary, question -> answer.

# %%
questions = [
    "Who developed the theory of Universal Grammar?",
    "What's the smallest unit of sound that changes meaning in a language?",
    "What do we call a baby's first-word stage, around age 1?",
    "Which brain area is mainly linked to language comprehension?",
    "What's it called when someone switches between languages mid-conversation?",
]

answers = [
    "Noam Chomsky",
    "A phoneme",
    "The holophrastic stage",
    "Wernicke's area",
    "Code-switching",
]
# Out:
# {'Who developed the theory of Universal Grammar?': 'Noam Chomsky',
#  "What's the smallest unit of sound that changes meaning in a language?": 'A phoneme',
#  "What do we call a baby's first-word stage, around age 1?": 'The holophrastic stage',
#  'Which brain area is mainly linked to language comprehension?': "Wernicke's area",
#  "What's it called when someone switches between languages mid-conversation?": 'Code-switching'}

# %% [markdown]
# **References for these questions** (in the same order as the list above):
#
# - Chomsky, N. (1965). *Aspects of the theory of syntax*. MIT Press.
# - Ladefoged, P., & Johnson, K. (2014). *A course in phonetics* (7th ed.). Cengage Learning.
# - Clark, E. V. (2009). *First language acquisition* (2nd ed.). Cambridge University Press.
# - Wernicke, C. (1874). *Der aphasische Symptomencomplex: Eine psychologische Studie auf anatomischer Basis*. Cohn & Weigert.
# - Poplack, S. (1980). Sometimes I'll start a sentence in Spanish y termino en español: Toward a typology of code-switching. *Linguistics, 18*(7–8), 581–618.

# %%
# build trivia_dict from questions and answers using zip() and dict()
dict(zip(questions, answers))
# Out:
# {'Who developed the theory of Universal Grammar?': 'Noam Chomsky',
#  "What's the smallest unit of sound that changes meaning in a language?": 'A phoneme',
#  "What do we call a baby's first-word stage, around age 1?": 'The holophrastic stage',
#  'Which brain area is mainly linked to language comprehension?': "Wernicke's area",
#  "What's it called when someone switches between languages mid-conversation?": 'Code-switching'}

# %% [markdown]
# **By the way:** `zip()` isn't just for building dicts. Since `questions` and `answers` are already two matched lists, you can hand that same pairing straight to `pandas` and get a table out of it:
#
# ```python
# import pandas as pd
#
# trivia_df = pd.DataFrame(zip(questions, answers), columns=["question", "answer"])
# trivia_df
# ```
#
# Same `zip()`, different destination -- a dict when you want to look things up by key, a DataFrame when you want rows and columns.

# %%
import pandas as pd

trivia_df = pd.DataFrame(zip(questions, answers), columns=["question", "answer"])
trivia_df
# Out:
#                                             question                  answer
# 0     Who developed the theory of Universal Grammar?            Noam Chomsky
# 1  What's the smallest unit of sound that changes...               A phoneme
# 2  What do we call a baby's first-word stage, aro...  The holophrastic stage
# 3  Which brain area is mainly linked to language ...         Wernicke's area
# 4  What's it called when someone switches between...          Code-switching

# %% [markdown]
# ### 11. Exploring the dictionary
#
# Using `trivia_dict` from the previous exercise (if you forget what a dict can do, `dir(trivia_dict)` will remind you, same trick you used on lists and strings):

# %%
# a. print all the questions (the dict's keys)


# b. print all the answers (the dict's values)


# c. print each question and answer together (the dict's items)


# d. look up the answer to "Who developed the theory of Universal Grammar?" directly by key

# %% [markdown]
# ### 12. Asking nicely with `.get()`
#
# Predict what happens if you look up a question that isn't in the dictionary using square brackets, e.g. `trivia_dict["What is the capital of France?"]`. Try it.

# %%
# try looking up a question that doesn't exist in trivia_dict, using square brackets
trivia_dict.get("What is the capital of France?", "Not one of our trivia questions!")
# Out:
# 'Not one of our trivia questions!'

# %% [markdown]
# Now try `.get()` instead:
#
# ```python
# trivia_dict.get("What is the capital of France?", "Not one of our trivia questions!")
# ```
#
# **Discuss:** `.get()` didn't crash — it quietly handed back the fallback text instead. This is a tiny taste of something you'll learn properly soon (`if`/`else`): a dictionary that can make a small decision about what to return, depending on whether a key exists or not.

# %%
# try trivia_dict.get() with a question that exists, and one that doesn't
trivia_dict.get("What is the capital of France?")
trivia_dict.get("Who developed the theory of Universal Grammar?")

# %% [markdown]
# ---

# %% [markdown]
# ## Mashup challenge: a list of trivia cards
#
# This combines everything so far: a **list**, where each item is a **dict**. Same five questions as Exercise 10 -- see the references listed there.

# %%
trivia_cards = [
    {"question": "Who developed the theory of Universal Grammar?",
     "answer": "Noam Chomsky", "category": "Linguists", "points": 10},
    {"question": "What's the smallest unit of sound that changes meaning?",
     "answer": "A phoneme", "category": "Phonology", "points": 5},
    {"question": "What's a baby's first-word stage called?",
     "answer": "The holophrastic stage", "category": "Language Acquisition", "points": 15},
    {"question": "Which brain area is linked to language comprehension?",
     "answer": "Wernicke's area", "category": "Neurolinguistics", "points": 10},
    {"question": "What's it called when someone switches languages mid-conversation?",
     "answer": "Code-switching", "category": "Bilingualism", "points": 5},
]

# %% [markdown]
# ### 13. Digging into the cards
#
# We haven't learned loops yet, so for now just reach into the list by index, then into that card by key.

# %%
# a. print the category of the first card (trivia_cards[0], then ["category"])


# b. print the question of the last card, using a negative index


# c. print, on one line, the category of every card (there are 5 -- write it out by hand for now;
#    once we learn loops, this exact task gets a lot less tedious)

# %% [markdown]
# ### 14. Extend: rebuild a summary line
#
# Using `.join()` (from the strings practice set) together with dictionary lookups, build one printable summary string for a single card, e.g.:
#
# `"[Phonology, 5 pts] What's the smallest unit of sound that changes meaning? -> A phoneme"`
#
# for `trivia_cards[1]`.

# %%
# build a formatted summary string for trivia_cards[1]
