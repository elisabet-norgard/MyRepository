# %%
import pandas as pd

# %%
raw = pd.read_csv("combined_data.csv")

# %%
raw
# Out:
#        participant_id  component_num  url  meta               sender  \
# 0                  51              1  NaN   NaN              Wecome1
# 1                  51              1  NaN   NaN              Wecome2
# 2                  51              1  NaN   NaN              Wecome3
# 3                  51              1  NaN   NaN        Instructions1
# 4                  51              1  NaN   NaN      Instructions 1a
# ...               ...            ...  ...   ...                  ...
# 15632              69              1  NaN   NaN           Short Loop
# 15633              69              1  NaN   NaN                Break
# 15634              69              1  NaN   NaN       Short Sequence
# 15635              69              1  NaN   NaN  Experiment Sequence
# 15636              69              1  NaN   NaN                 root
#
#          sender_type sender_id    ended_on   duration  time_run  ...  \
# ...

# %%
# choose the number of rows we want to look at
raw.head(20)
# Out:
#     participant_id  component_num  url  meta             sender  \
# 0               51              1  NaN   NaN            Wecome1
# 1               51              1  NaN   NaN            Wecome2
# 2               51              1  NaN   NaN            Wecome3
# 3               51              1  NaN   NaN      Instructions1
# 4               51              1  NaN   NaN    Instructions 1a
# 5               51              1  NaN   NaN      Instructions2
# 6               51              1  NaN   NaN      Instructions3
# 7               51              1  NaN   NaN      Instructions4
# 8               51              1  NaN   NaN      Instructions5
# 9               51              1  NaN   NaN           fixation
# 10              51              1  NaN   NaN              mask1
# 11              51              1  NaN   NaN              prime
# 12              51              1  NaN   NaN              mask2
# 13              51              1  NaN   NaN             target
# ...

# %%
list(raw)
# Out:
# ['participant_id',
#  'component_num',
#  'url',
#  'meta',
#  'sender',
#  'sender_type',
#  'sender_id',
#  'ended_on',
#  'duration',
#  'time_run',
#  'time_render',
#  'time_show',
#  'time_end',
#  'time_commit',
#  'timestamp',
#  'time_switch',
#  'response',
#  'response_action',
#  'prime',
#  'target',
#  'condition',
#  'soa_condition',
#  'congruence',
#  'correct_response',
#  'correctResponse',
#  'correct']

# %%
cols = ['participant_id', 'duration', 'prime', 'target','response', 'condition', 'soa_condition', 'congruence', 'correct_response', 'correct']

# %%
df = raw[cols]

# %%
df
# Out:
#        participant_id   duration prime target response condition  \
# 0                  51     499.56   NaN    NaN      NaN       NaN
# 1                  51     499.52   NaN    NaN      NaN       NaN
# 2                  51     499.52   NaN    NaN      NaN       NaN
# 3                  51    9061.10   NaN    NaN      NaN       NaN
# 4                  51    2279.00   NaN    NaN      NaN       NaN
# ...               ...        ...   ...    ...      ...       ...
# 15632              69   85426.00   NaN    NaN      NaN       NaN
# 15633              69     868.30   NaN    NaN      NaN       NaN
# 15634              69   86318.40   NaN    NaN      NaN       NaN
# 15635              69  183618.50   NaN    NaN      NaN       NaN
# 15636              69  216385.18   NaN    NaN      NaN       NaN
#
#       soa_condition congruence correct_response correct
# 0               NaN        NaN              NaN     NaN
# 1               NaN        NaN              NaN     NaN
# ...

# %%
df = df[df['sender'] == 'target']

# %%
df
# Out:
#        participant_id  sender  duration response        condition  \
# 13                 51  target    843.38        n         practice
# 19                 51  target    593.04        m         practice
# 25                 51  target    559.18        m         practice
# 31                 51  target    653.76        n         practice
# 40                 51  target    520.14        m  Inc_Synth_Synth
# ...               ...     ...       ...      ...              ...
# 15606              69  target    699.20        m        Con_Synth
# 15612              69  target    580.20        n          Con_Nat
# 15618              69  target    577.90        m    Inc_Nat_Synth
# 15624              69  target    661.10        n    Inc_Synth_Nat
# 15630              69  target    709.20        n      Inc_Nat_Nat
#
#       soa_condition   congruence correct_response correct
# 13         practice     practice                n    True
# ...

# %%
sender_list = list(df['sender'])

# %%
# sender_list not going to actually run this bc it produces way too many lines of output

# %%
df['sender'].unique()
# Out:
# <StringArray>
# ['target']
# Length: 1, dtype: str

# %%
df = df[df['condition'] != 'practice']

# %%
df = df.drop(columns = ['sender'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df = df.drop(columns = ['sender'])
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4628         obj = self
#    4629
#    4630         for axis, labels in axes.items():
#    4631             if labels is not None:
# ...

# %%
df
# Out:
#        participant_id   duration prime target response condition  \
# 0                  51     499.56   NaN    NaN      NaN       NaN
# 1                  51     499.52   NaN    NaN      NaN       NaN
# 2                  51     499.52   NaN    NaN      NaN       NaN
# 3                  51    9061.10   NaN    NaN      NaN       NaN
# 4                  51    2279.00   NaN    NaN      NaN       NaN
# ...               ...        ...   ...    ...      ...       ...
# 15632              69   85426.00   NaN    NaN      NaN       NaN
# 15633              69     868.30   NaN    NaN      NaN       NaN
# 15634              69   86318.40   NaN    NaN      NaN       NaN
# 15635              69  183618.50   NaN    NaN      NaN       NaN
# 15636              69  216385.18   NaN    NaN      NaN       NaN
#
#       soa_condition congruence correct_response correct
# 0               NaN        NaN              NaN     NaN
# 1               NaN        NaN              NaN     NaN
# ...

# %%
df
# Out:
#        participant_id   duration prime target response condition  \
# 0                  51     499.56   NaN    NaN      NaN       NaN
# 1                  51     499.52   NaN    NaN      NaN       NaN
# 2                  51     499.52   NaN    NaN      NaN       NaN
# 3                  51    9061.10   NaN    NaN      NaN       NaN
# 4                  51    2279.00   NaN    NaN      NaN       NaN
# ...               ...        ...   ...    ...      ...       ...
# 15632              69   85426.00   NaN    NaN      NaN       NaN
# 15633              69     868.30   NaN    NaN      NaN       NaN
# 15634              69   86318.40   NaN    NaN      NaN       NaN
# 15635              69  183618.50   NaN    NaN      NaN       NaN
# 15636              69  216385.18   NaN    NaN      NaN       NaN
#
#       soa_condition congruence correct_response correct
# 0               NaN        NaN              NaN     NaN
# 1               NaN        NaN              NaN     NaN
# ...

# %%
df.loc[df['target'] == 'BULL', 'correct_response'] = 'n'

# %%
# df['accuracy'] = df['response'] == df['correct_response']

# %%
df
# Out:
#        participant_id   duration prime target response condition  \
# 0                  51     499.56   NaN    NaN      NaN       NaN
# 1                  51     499.52   NaN    NaN      NaN       NaN
# 2                  51     499.52   NaN    NaN      NaN       NaN
# 3                  51    9061.10   NaN    NaN      NaN       NaN
# 4                  51    2279.00   NaN    NaN      NaN       NaN
# ...               ...        ...   ...    ...      ...       ...
# 15632              69   85426.00   NaN    NaN      NaN       NaN
# 15633              69     868.30   NaN    NaN      NaN       NaN
# 15634              69   86318.40   NaN    NaN      NaN       NaN
# 15635              69  183618.50   NaN    NaN      NaN       NaN
# 15636              69  216385.18   NaN    NaN      NaN       NaN
#
#       soa_condition congruence correct_response correct  accuracy
# 0               NaN        NaN              NaN     NaN     False
# ...

# %%
# df_e = df[df['participant_id'] == 46]

# %%
df = df.reset_index()

# %%
df
# Out:
#        index  participant_id   duration prime target response condition  \
# 0          0              51     499.56   NaN    NaN      NaN       NaN
# 1          1              51     499.52   NaN    NaN      NaN       NaN
# 2          2              51     499.52   NaN    NaN      NaN       NaN
# 3          3              51    9061.10   NaN    NaN      NaN       NaN
# 4          4              51    2279.00   NaN    NaN      NaN       NaN
# ...      ...             ...        ...   ...    ...      ...       ...
# 15176  15632              69   85426.00   NaN    NaN      NaN       NaN
# 15177  15633              69     868.30   NaN    NaN      NaN       NaN
# 15178  15634              69   86318.40   NaN    NaN      NaN       NaN
# 15179  15635              69  183618.50   NaN    NaN      NaN       NaN
# 15180  15636              69  216385.18   NaN    NaN      NaN       NaN
#
#       soa_condition congruence correct_response correct  accuracy
# ...

# %%
df_grouped = df.groupby(['soa_condition', 'congruence']).mean(['duration'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df_grouped = df.groupby(['soa_condition', 'congruence']).mean(['duration'])
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# ...

# %%
df_grouped = df_grouped.reset_index()
df_grouped
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 df_grouped = df_grouped.reset_index()
#       2 df_grouped
#
# NameError: name 'df_grouped' is not defined

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
ax = sns.barplot(data = df, x = 'soa_condition', y = 'duration', hue = 'congruence')

#ax = sns.barplot(data = df_grouped, x = 'soa_condition', y = 'duration', hue = 'congruence')

sns.move_legend(ax, "lower right")
