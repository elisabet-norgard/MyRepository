# %%
#slicing
#type
#len
#pandas dataframes

# %%
a = [4, 5, 8, 5, 6, 7, 9, 10]

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 8

# %%
b = "I am a string!"
len(b)
# Out:
# 14

# %%
a[3:]     #starts with position 3 and then continues to the end
# Out:
# [5, 6, 7, 9, 10]

# %%
# s[-2:]

# %%
import pandas as pd

# %%
a = [3, 4, 78, 6]
b = [43, 42, 178, 76]
c = [38, 45, 728, 46]

# %%
arla = pd.DataFrame({'a': a, 'b' : b, 'c' : c})
arla
# Out:
#     a    b    c
# 0   3   43   38
# 1   4   42   45
# 2  78  178  728
# 3   6   76   46

# %%
d = arla['a']

# %%
type(d)
# Out:
# pandas.Series

# %%
e = list(d)

# %%
e
# Out:
# [3, 4, 78, 6]

# %%
arla["row_mean"] = arla.mean(axis=1)

# %%
arla
# Out:
#     a    b    c    row_mean
# 0   3   43   38   28.000000
# 1   4   42   45   30.333333
# 2  78  178  728  328.000000
# 3   6   76   46   42.666667

# %%
df = pd.read_csv('/work/MyRepository/Stroop-raw-over-the-years.csv')

# %%
df
# Out:
#      Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int  Year
# 0             4.16        6.76          4.45         4.65  2015
# 1             4.35        7.73          4.78         4.46  2015
# 2             3.60        7.00          4.00         3.50  2015
# 3             3.90        9.03          4.60         6.30  2015
# 4             4.22        9.98          6.83         6.24  2015
# ..             ...         ...           ...          ...   ...
# 200           4.77       10.00          5.66         6.24  2025
# 201           4.61       12.80          6.87         9.55  2025
# 202           4.79       10.72          5.64         7.25  2025
# 203           4.41        8.87          6.70         6.70  2025
# 204           5.50        9.80          6.20        21.70  2025
#
# [205 rows x 5 columns]

# %%
pd.df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 pd.info
#
# AttributeError: module 'pandas' has no attribute 'info'

# %%
df['meanRT'] = df.drop(['Year'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df['meanRT'] = df.drop(['Year'], axis = 1)
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/frame.py:4662, in DataFrame.__setitem__(self, key, value)
#    4658             self._setitem_frame(key, value)
#    4659         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4660             self._setitem_array(key, value)
#    4661         elif isinstance(value, DataFrame):
# -> 4662             self._set_item_frame_value(key, value)
#    4663         elif (
#    4664             is_list_like(value)
#    4665             and not self.columns.is_unique
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/frame.py:4827, in DataFrame._set_item_frame_value(self, key, value)
#    4823
#    4824             return self.isetitem(locs, value)
#    4825
# ...
